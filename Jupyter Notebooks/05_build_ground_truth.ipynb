# %% [markdown]
# # 05: Build Ground Truth Validation Dataset
#
# ## Objective
# Build a validation dataset to evaluate whether an LLM can correctly determine if a paper should be **included** or **excluded** from a Cochrane systematic review.
#
# All reviews in this dataset belong to the **Cochrane Public Health** group, since our
# 119 manually downloaded PDFs (notebook 02) are already scoped to that group.
#
# ## Revised Label Logic
# - **Included (label=1)**: ALL papers referenced in any Cochrane review, regardless of their
#   internal categorization (included, excluded, awaiting, ongoing). If human reviewers
#   mentioned it, it was relevant enough to consider.
# - **Excluded (label=0)**: Papers retrieved by the review's PubMed search strategy but
#   NOT referenced in any Cochrane review. These are true negatives — the search found them
#   but reviewers did not include them.
#
# ## What the LLM needs to decide
# Given:
# - **Review context** (title and abstract of the Cochrane systematic review)
# - **Paper abstract** (a candidate paper being screened)
#
# Predict:
# - **Label = 1** → Paper should be INCLUDED in the review
# - **Label = 0** → Paper should be EXCLUDED from the review
#
# ## Data structure
# Each row in the validation set contains:
# 1. `review_doi` - CD number of the Cochrane systematic review (e.g., CD001047)
# 2. `review_title` - Title of the Cochrane systematic review
# 3. `review_abstract` - Full structured abstract from the PDF (Background through Authors' conclusions)
# 4. `paper_id` - Unique identifier for the candidate paper
# 5. `paper_title` - Title of the candidate paper
# 6. `paper_abstract` - Abstract of the candidate paper
# 7. `label` - Ground truth (1=included, 0=excluded)
# 8. `source` - Origin of the paper ("cochrane_ref" or "pubmed_search")
#
# ## Input Files
# - `Data/referenced_paper_abstracts.csv` — Papers referenced in Cochrane reviews (notebook 03) → **all label=1**
# - `Data/pubmed_excluded_abstracts.csv` — PubMed search-only papers (notebook 04) → **all label=0**
# - `Data/review_metadata.csv` — Review metadata with full structured abstracts extracted from PDFs (notebook 02)
#
# ## Output
# - `Data/ground_truth_validation_dataset.csv` - Full validation dataset

# %%
# Install required packages
# %pip install -q pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# =============================================================================
# Load All Data Sources
# =============================================================================
from pathlib import Path
import pandas as pd

notebook_dir = Path.cwd()
project_root = notebook_dir if (notebook_dir / "Data").exists() else notebook_dir.parent
DATA_DIR = project_root / "Data"

# Input files
INCLUDED_CSV  = DATA_DIR / "referenced_paper_abstracts.csv"   # from notebook 03
EXCLUDED_CSV  = DATA_DIR / "pubmed_excluded_abstracts.csv"     # from notebook 04
META_CSV      = DATA_DIR / "review_metadata.csv"               # from notebook 02
OUTPUT_CSV    = DATA_DIR / "ground_truth_validation_dataset.csv"

# --- Review metadata (with full structured abstracts from PDFs) ---
# One row per PDF (119 reviews, one per CD number — no version duplicates)
print("Loading review metadata...")
meta = pd.read_csv(META_CSV)
print(f"  Reviews: {len(meta):,}")

review_dois = set(meta['doi'].dropna())

# --- Included papers (ALL Cochrane references) ---
print("\nLoading included papers (Cochrane references)...")
included_raw = pd.read_csv(INCLUDED_CSV)
print(f"  Total rows: {len(included_raw):,}")
assert 'review_doi' in included_raw.columns, "ERROR: review_doi missing! Re-run notebook 03."
included_raw = included_raw[included_raw['review_doi'].isin(review_dois)]
print(f"  Matching our reviews: {len(included_raw):,}")

# --- Excluded papers (PubMed search-only) ---
print("\nLoading excluded papers (PubMed search results)...")
excluded_raw = pd.read_csv(EXCLUDED_CSV)
print(f"  Total rows: {len(excluded_raw):,}")
excluded_raw = excluded_raw[excluded_raw['review_doi'].isin(review_dois)]
print(f"  Matching our reviews: {len(excluded_raw):,}")

print(f"\nReview metadata: {len(meta):,} reviews")
print(f"  With abstract: {meta['abstract'].notna().sum():,}")
print(f"  Mean abstract length: {meta['abstract'].str.len().mean():.0f} chars")
# Out:
# Loading review metadata...
#   Total reviews: 119
#   Latest versions: 119
#
# Loading included papers (Cochrane references)...
#   Total rows: 10,422
#   After filtering to latest reviews: 10,422
#
# Loading excluded papers (PubMed search results)...
#   Total rows: 10,182
#   After filtering to latest reviews: 10,182
#
# Review metadata (latest): 119 reviews
#   With abstract: 117
#   Mean abstract length: 5017 chars

# %%
# =============================================================================
# Prepare Included Papers (label=1)
# =============================================================================
# ALL papers referenced in Cochrane reviews — regardless of internal category
# (included, excluded, awaiting, ongoing) — are label=1.

print("INCLUDED PAPERS (label=1)")
print("=" * 60)

# Filter to rows with usable abstracts
included = included_raw[
    included_raw['abstract'].notna() &
    (included_raw['abstract'].str.len() > 50)
].copy()
print(f"With abstracts (>50 chars): {len(included):,}")

# Deduplicate (study_id, review_doi)
included = included.drop_duplicates(subset=['study_id', 'review_doi'], keep='first')
print(f"After dedup: {len(included):,}")

# Standardize columns for merge
included_clean = included[['review_doi', 'original_title', 'abstract']].rename(columns={
    'original_title': 'paper_title',
    'abstract': 'paper_abstract',
})
included_clean['label'] = 1
included_clean['source'] = 'cochrane_ref'

# Also keep PMID as a unique paper ID where available
if 'pmid' in included.columns:
    included_clean['pmid'] = included['pmid'].values

print(f"\nIncluded papers prepared: {len(included_clean):,}")
print(f"  Unique reviews: {included_clean['review_doi'].nunique():,}")
print(f"  Original categories: {dict(included['category'].value_counts())}")
# Out:
# INCLUDED PAPERS (label=1)
# ============================================================
# With abstracts (>50 chars): 9,876
# After dedup: 8,043
#
# Included papers prepared: 8,043
#   Unique reviews: 113
#   Original categories: {'excluded': np.int64(3195), 'additional': np.int64(2611), 'included': np.int64(1990), 'awaiting': np.int64(142), 'ongoing': np.int64(74), 'other_versions': np.int64(31)}

# %%
# =============================================================================
# Prepare Excluded Papers (label=0)
# =============================================================================
# Papers found by PubMed search strategies but NOT in any Cochrane review.

print("EXCLUDED PAPERS (label=0)")
print("=" * 60)

# Excluded already filtered to abstract > 50 chars in notebook 05
excluded = excluded_raw.copy()
print(f"Excluded papers loaded: {len(excluded):,}")

# Standardize columns
excluded_clean = excluded[['review_doi', 'title', 'abstract']].rename(columns={
    'title': 'paper_title',
    'abstract': 'paper_abstract',
})
excluded_clean['label'] = 0
excluded_clean['source'] = 'pubmed_search'

if 'pmid' in excluded.columns:
    excluded_clean['pmid'] = excluded['pmid'].values

print(f"Excluded papers prepared: {len(excluded_clean):,}")
print(f"  Unique reviews: {excluded_clean['review_doi'].nunique():,}")

# =============================================================================
# Combine Included + Excluded
# =============================================================================

print("\n" + "=" * 60)
print("COMBINING DATASETS")
print("=" * 60)

combined = pd.concat([included_clean, excluded_clean], ignore_index=True)
print(f"Combined total: {len(combined):,}")
print(f"  Included (label=1): {(combined['label'] == 1).sum():,}")
print(f"  Excluded (label=0): {(combined['label'] == 0).sum():,}")
# Out:
# EXCLUDED PAPERS (label=0)
# ============================================================
# Excluded papers loaded: 10,182
# Excluded papers prepared: 10,182
#   Unique reviews: 35
#
# ============================================================
# COMBINING DATASETS
# ============================================================
# Combined total: 18,225
#   Included (label=1): 8,043
#   Excluded (label=0): 10,182

# %%
# =============================================================================
# Join with Review Context (title, abstract from PDFs)
# =============================================================================

print("JOINING WITH REVIEW CONTEXT")
print("=" * 60)

# Review context comes directly from review_metadata.csv (notebook 02)
# Both sides use CD numbers as review_doi, so the join is straightforward.
reviews_clean = meta[['doi', 'title', 'abstract']].rename(columns={
    'doi': 'review_doi',
    'title': 'review_title',
    'abstract': 'review_abstract',
}).drop_duplicates(subset='review_doi', keep='first')

print(f"Unique reviews with context: {len(reviews_clean):,}")

# Join on review_doi (CD number)
ground_truth = combined.merge(reviews_clean, on='review_doi', how='inner')
print(f"Papers matched to reviews: {len(ground_truth):,}")

# Filter to reviews with meaningful abstracts
ground_truth = ground_truth[
    ground_truth['review_abstract'].notna() &
    (ground_truth['review_abstract'].str.len() > 100)
]
print(f"With review abstract > 100 chars: {len(ground_truth):,}")

# ── Assign unique paper IDs ───────────────────────────────────────────────────
# Use PMID where available, otherwise assign a sequential ID with prefix
ground_truth['paper_id'] = None

# Papers with PMIDs get "PMID:<number>"
if 'pmid' in ground_truth.columns:
    has_pmid = ground_truth['pmid'].notna()
    ground_truth.loc[has_pmid, 'paper_id'] = 'PMID:' + ground_truth.loc[has_pmid, 'pmid'].astype(int).astype(str)
    print(f"\nPaper IDs from PMID: {has_pmid.sum():,}")

# Papers without PMIDs get "PAPER:<sequential number>"
no_id = ground_truth['paper_id'].isna()
if no_id.any():
    ground_truth.loc[no_id, 'paper_id'] = [f"PAPER:{i+1}" for i in range(no_id.sum())]
    print(f"Paper IDs assigned sequentially: {no_id.sum():,}")

# Final column selection
cols = [
    'review_doi',
    'review_title',
    'review_abstract',
    'paper_id',
    'paper_title',
    'paper_abstract',
    'label',
    'source',
]
ground_truth = ground_truth[cols].copy()

print(f"\nVALIDATION DATASET STRUCTURE")
print("=" * 60)
print(f"Total examples: {len(ground_truth):,}")
print(f"\nLabel distribution:")
print(f"  Included (label=1): {(ground_truth['label'] == 1).sum():,}")
print(f"  Excluded (label=0): {(ground_truth['label'] == 0).sum():,}")
print(f"  Ratio (excl/incl):  {(ground_truth['label'] == 0).sum() / max((ground_truth['label'] == 1).sum(), 1):.1f}x")
print(f"\nUnique reviews: {ground_truth['review_doi'].nunique():,}")
print(f"Unique paper IDs: {ground_truth['paper_id'].nunique():,}")

print("\n" + "=" * 60)
print("SAMPLE ROW (what the LLM will see):")
print("=" * 60)
sample = ground_truth.iloc[0]
print(f"\nREVIEW DOI: {sample['review_doi']}")
print(f"REVIEW TITLE: {sample['review_title'][:100]}...")
print(f"\nREVIEW ABSTRACT: {sample['review_abstract'][:300]}...")
print(f"\nPAPER ID: {sample['paper_id']}")
print(f"PAPER TITLE: {sample['paper_title']}")
print(f"\nPAPER ABSTRACT: {sample['paper_abstract'][:300]}...")
print(f"\nLABEL: {sample['label']} ({'INCLUDED' if sample['label']==1 else 'EXCLUDED'})")
print(f"SOURCE: {sample['source']}")
# Out:
# JOINING WITH REVIEW CONTEXT
# ============================================================
# Unique reviews with context: 119
# Papers matched to reviews: 18,225
# With review abstract > 100 chars: 18,225
#
# Paper IDs from PMID: 17,665
# Paper IDs assigned sequentially: 560
#
# VALIDATION DATASET STRUCTURE
# ============================================================
# Total examples: 18,225
#
# Label distribution:
#   Included (label=1): 8,043
#   Excluded (label=0): 10,182
#   Ratio (excl/incl):  1.3x
#
# Unique reviews: 114
# Unique paper IDs: 17,095
#
# ============================================================
# SAMPLE ROW (what the LLM will see):
# ============================================================
#
# REVIEW DOI: CD001047
# REVIEW TITLE: Pool fencing for preventing drowning of children (Review) Thompson DC, Rivara F Thompson DC, Rivara ...
#
# REVIEW ABSTRACT: Background: In most industrialized countries, drowning ranks second or third behind motor vehicles and fires as a cause of unintentional injury deaths to children under the age of 15. Death rates from drowning are highest in children less than five years old. Pool fencing is a passive environmental ...
#
# PAPER ID: PMID:2034145
# PAPER TITLE: Childhood drowning and near-drowning in Brisbane: the contribution of domestic pools
#
# PAPER ABSTRACT: To describe the epidemiology of domestic swimming pool drowning and near-drowning in Brisbane and to examine the efficacy of a broad range of preventive options, including pool fences. A prospective, hospital-based, injury surveillance system to describe the epidemiology of drowning and near-drownin...
#
# LABEL: 1 (INCLUDED)
# SOURCE: cochrane_ref

# %%
# =============================================================================
# Save Validation Dataset
# =============================================================================

ground_truth.to_csv(OUTPUT_CSV, index=False)

print("GROUND TRUTH VALIDATION DATASET COMPLETE")
print("=" * 60)
print(f"\n✓ Saved to {OUTPUT_CSV.name}")
print(f"  Total examples:    {len(ground_truth):,}")
print(f"  Included (label=1): {(ground_truth['label'] == 1).sum():,}")
print(f"  Excluded (label=0): {(ground_truth['label'] == 0).sum():,}")
print(f"  Unique reviews:    {ground_truth['review_doi'].nunique():,}")

print(f"\nSource breakdown:")
print(ground_truth['source'].value_counts().to_string())

print(f"\n✓ Ready for notebook 06 (LLM evaluation)!")
# Out:
# GROUND TRUTH VALIDATION DATASET COMPLETE
# ============================================================
#
# ✓ Saved to ground_truth_validation_dataset.csv
#   Total examples:    18,225
#   Included (label=1): 8,043
#   Excluded (label=0): 10,182
#   Unique reviews:    114
#
# Source breakdown:
# source
# pubmed_search    10182
# cochrane_ref      8043
#
# ✓ Ready for notebook 06 (LLM evaluation)!
